# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#setting warning version for a project 
import warnings
warnings.filterwarning("ignore")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-651b5bce18d2> in <module>
#       1 #setting warning version for a project
#       2 import warnings
# ----> 3 warnings.filterwarning("ignore")
#
# AttributeError: module 'warnings' has no attribute 'filterwarning'

# %%
iris = pd.read_csv("iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris["Species"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.plot(kind=  "scatter", x = "SepalLengthCm", y = "SepalWidthCm" )
plt.title("iris_plotting")
# Out:
# Text(0.5, 1.0, 'iris_plotting')

# %%
#scatter plot using seaborn

sns.jointplot(x ="SepalLengthCm", y = "SepalWidthCm" ,data = iris , size = 6)
# Out:
# C:\Users\Danish Ahmad\anaconda3\lib\site-packages\seaborn\axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(iris,hue="Species",size = 5).map(plt.scatter,"SepalLengthCm","SepalWidthCm")
# Out:
# C:\Users\Danish Ahmad\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(iris,hue="Species",size = 5).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()
# Out:
# C:\Users\Danish Ahmad\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x = "Species" , y = "PetalLengthCm" , data =iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.FacetGrid(iris,hue="Species").map(sns.kdeplot,"PetalLengthCm").add_legend()

# %%
sns.FacetGrid(iris,hue="Species").map(plt.plot,"PetalLengthCm").add_legend()

# %%
iris.plot(kind = "bar" , x ="Species", y = "PetalLengthCm" , color = "k")
# Out:
# <AxesSubplot:xlabel='Species'>

# %%
iris.plot(kind = "hist" , x ="Species", y = "PetalLengthCm" , color = "k")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#graph matplotlib
#line chart
# %matplotlib inline
#showing growth of apple tons per hectare in 6 years
y = [ 0.895, 0.91 , 0.919, 0.945 , 0.443 ,0.785]

# %%
plt.plot(y)

# %%
year =[2010 , 2011 , 2012 , 2013 , 2014 , 2015]
growth = [ 0.895, 0.91 , 0.919, 0.945 , 0.443 ,0.785]
plt.plot(year,growth)

# %%
#axis label
plt.xlabel("year")
plt.ylabel("growth")
plt.legend()
plt.title("yield")
year =[2010 , 2011 , 2012 , 2013 , 2014 , 2015]
growth = [ 0.895, 0.91 , 0.919, 0.945 , 0.443 ,0.785]
plt.plot(year,growth)
# Out:
# No handles with labels found to put in legend.

# %%
#plotting multiple lines 
year =[2010 , 2011 , 2012 , 2013 , 2014 , 2015]
apples = [ 0.895, 0.91 , 0.919, 0.945 , 0.443 ,0.785]
oranges= [ 0.95, 0.891 , 0.95, 0.45 , 0.43 ,0.85]
plt.plot(year,apples)
plt.plot(year,oranges)
plt.legend(["apples","oranges"])

# %%
#line marker
plt.plot(year,apples,oranges,marker="o" , c ="r", ls="-")
plt.plot(year,apples,oranges,marker="x", c ="k", ls="--")
plt.legend(["apples","oranges"])
